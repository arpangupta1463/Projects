# %%
import tensorflow as tf 
import cv2
import os 
import matplotlib.pyplot as plt
import numpy as np

# %%
img_array=cv2.imread("test_set/closed_eyes/s0015_00017_0_0_0_0_1_01.png",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_array,cmap='gray')

# %%
img_array.shape
# Out:
# (119, 119)

# %%
Datadirectory = "train_set/"
classes = ["closed_eyes","opened_eyes"]
for category in classes:
    path = os.path.join(Datadirectory,category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        backtorgb = cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
        plt.imshow(img_array,cmap='gray')
        plt.show()
        break
    break

# %%
img_size =224
new_array = cv2.resize(backtorgb,(img_size,img_size))
plt.imshow(img_array,cmap='gray')
plt.show()

# %% [markdown]
# # reading all images and converting them into an array for data and labels

# %%
training_data =[]

def create_training_data():
    for category in classes:
        path = os.path.join(Datadirectory,category)
        class_num = classes.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                backtorgb = cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
                new_array = cv2.resize(backtorgb,(img_size,img_size))
                training_data.append(new_array,class_num)
            except Exception as e:
                pass

# %%
create_training_data()

# %%
print(len(training_data))
# Out:
# 0
